# %%
import ASTMD

# %%
# ASTMD.790(filenames, widths, depths, span, mtr_name="", largespan=True, validate_modulus=False)
Material_Flexion = ASTMD.D790(["Flexion/g3_4.txt","Flexion/g3_6.txt"], [25.4, 25.4], [2.1, 2.2], 150, mtr_name="Carbon UD", largespan=True)

# %%
results_flexion = open("Flexion/results_D790.txt").read()
print(results_flexion)
# Out:
# ASTM D790 Standard Report
#
# 1. Testing parameters
# Material name : Carbon UD
# Width of samples : 25.4mm, 25.4mm
# Depths of samples : 2.1mm, 2.2mm
# Span used : 150 (Large span)
#
# 2. Test Results
# Tangent modulus : 135908.0 MPa
# Standard Deviation : (12727.0)
# Flexural strength : 139.0 MPa
# Standard Deviation : (10.0)

# %%
# Material = ASTMD.D3039(filenames, widths, thicknesses, lengths, mtr_name="", extensiometer_length=50.8)
Material_Tension = ASTMD.D3039(["Tension/0_1.txt", "Tension/0_2.txt"], [15, 15], [1.1, 1.11], [200, 201], mtr_name="mtr_tension")

# %%
results_tension = open("Tension/results_D3039.txt").read()
print(results_tension)
# Out:
# ASTM D3039 Standard Report
#
# 1. Testing parameters
# Material name : mtr_tension
# Width of samples : 15mm, 15mm
# Thickness of samples : 1.1mm, 1.11mm
# Lengths of samples : 200mm, 201mm
# Extensometer length : 50.8mm
#
# 2. Test Results
# Chord tensile modulus : 14339.0 MPa
# Standard Deviation : (133.0)
# Tensile strength : 161.0 MPa
# Standard Deviation : (6.0)

# %%
# Material = ASTMD.D5868(filenames, areas, mtr_name="")
Material_shear = ASTMD.D5868(["Lap Shear/S_1.txt", "Lap Shear/S_2.txt"], [25.4**2, 25.4**2], mtr_name = "mtr lap shear")

# %%
results_shear = open("Lap Shear/results_D5868.txt").read()
print(results_shear)
# Out:
# ASTM D5868 Standard Report
#
# 1. Testing parameters
# Material name : mtr lap shear
# Areas of bonded joints : 645.16 mm^2, 645.16 mm^2
#
# 2. Test Results
# Individual Shear strengths : 3.249Mpa, 2.619 MPa
# Average Shear strength : 2.93 MPa
# Standard Deviation : (0.45)
